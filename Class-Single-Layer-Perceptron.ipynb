# %% [markdown]
# <div style="text-align: justify">
# <b><h1>SLP - Single-layer Perceptron</h1></b>
# <br>
# • Linear classifier, ie, performs classification of linearly separable sets (labeled in this example as -1 and 1).
#
# <div style="text-align: justify">
# <b><h2>Configuration of Single-layer Perceptron</h2></b>
#
# <br>
# The Weights are initialized as zeros, the Threshold and Bias are respectively set to 0 and 1
# </div>
#
# <br>
# <b><h2>Imports</h2></b>
# <br>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# Data Dictionary
data_dictionary = {
    # 'Keys' : 'Values',
    '0.72,0.82' : '-1',
    '0.91,-0.69' : '-1',
    '0.03,0.93' : '-1',
    '0.12,0.25' : '-1',
    '0.96,0.47' : '-1',
    '0.8,-0.75' : '-1',
    '0.46,0.98' : '-1',
    '0.66,0.24' : '-1',
    '0.72,-0.15' : '-1',
    '0.35,0.01' : '-1',
    '-0.11,0.1' : '1',
    '0.31,-0.96' : '1',
    '0.0,-0.26' : '1',
    '-0.43,-0.65' : '1',
    '0.57,-0.97' : '1',
    '-0.72,-0.64' : '1',
    '-0.25,-0.43' : '1',
    '-0.12,-0.9' : '1',
    '-0.58,0.62' : '1',
    '-0.77,-0.76' : '1'
}

# %%
# Weights (Synapses)
w = [0,0]

# Theshold
threshold = 0

# Bias
bias = 1

# Learning rate - [0, 1]
learning_rate = 1

# Maximum number allowed of iterations
max_iterations = 100

# Output
y = 0

# %%
for k in range(1, max_iterations):
    hits = 0
    print("\n------------------------- ITERATION "+str(k)+" ------------------------- ")

    for i in range(0,len(x)):
        sum = 0

        # Weighted sum
        for j in range(0,len(x[i])-1):
            sum += x[i][j] * w[j]
            print(" x[",i,"][",j,"] ",x[i][j]," w[",j,"] "," sum ",sum)
        # Output = Bias + Weighted sum
        output = bias + sum
        # Output is determined by the Threshold
        
        if output >= threshold:
            print(output, " >= ", threshold, " Hence a 1")
            y = 1
        else:
            print(output, " < ", threshold, " Hence a -1")
            y = -1     
        # Update the Weights if the output does not match with the Desired output
        if y == x[i][2]:
            hits += 1
            answer = "Correct!"
        else:
            print("length of weight len(",w,")", len(w))
            for j in range (0,len(w)):
                
                #print(" weight before w[","j] ",w[j])
                w[j] = w[j] + (learning_rate * x[i][2] * x[i][j])
                #print(" weight after w[","j] ",w[j])
            bias = bias + learning_rate * x[i][2]

    if hits == len(x):
        print("\n---------------------------------------------------------------")
        print("\nw[0] w[1] ",w[0]," ",w[1])
        print("\nFunctionality learned with "+str(k)+" iterations!")
        break;
print("\nDone!\n")
# Out:
# ------------------------- ITERATION 1 -------------------------
#  x[ 0 ][ 0 ]  0.72  w[ 0 ]   sum  0.0
#  x[ 0 ][ 1 ]  0.82  w[ 1 ]   sum  0.0
# 1.0  >=  0  Hence a 1
# length of weight len( [0, 0] ) 2
#  x[ 1 ][ 0 ]  0.91  w[ 0 ]   sum  -0.6552
#  x[ 1 ][ 1 ]  -0.69  w[ 1 ]   sum  -0.08940000000000003
# -0.08940000000000003  <  0  Hence a -1
#  x[ 2 ][ 0 ]  0.03  w[ 0 ]   sum  -0.021599999999999998
#  x[ 2 ][ 1 ]  0.93  w[ 1 ]   sum  -0.7841999999999999
# -0.7841999999999999  <  0  Hence a -1
#  x[ 3 ][ 0 ]  0.12  w[ 0 ]   sum  -0.08639999999999999
#  x[ 3 ][ 1 ]  0.25  w[ 1 ]   sum  -0.2914
# -0.2914  <  0  Hence a -1
#  x[ 4 ][ 0 ]  0.96  w[ 0 ]   sum  -0.6911999999999999
#  x[ 4 ][ 1 ]  0.47  w[ 1 ]   sum  -1.0766
# -1.0766  <  0  Hence a -1
#  x[ 5 ][ 0 ]  0.8  w[ 0 ]   sum  -0.576
#  x[ 5 ][ 1 ]  -0.75  w[ 1 ]   sum  0.039000000000000035
# 0.039000000000000035  >=  0  Hence a 1
# length of weight len( [-0.72, -0.82] ) 2
#  x[ 6 ][ 0 ]  0.46  w[ 0 ]   sum  -0.6992
#  x[ 6 ][ 1 ]  0.98  w[ 1 ]   sum  -0.7678
# -1.7678  <  0  Hence a -1
#  x[ 7 ][ 0 ]  0.66  w[ 0 ]   sum  -1.0032
#  x[ 7 ][ 1 ]  0.24  w[ 1 ]   sum  -1.02
# -2.02  <  0  Hence a -1
#  x[ 8 ][ 0 ]  0.72  w[ 0 ]   sum  -1.0944
#  x[ 8 ][ 1 ]  -0.15  w[ 1 ]   sum  -1.0839
# -2.0839  <  0  Hence a -1
#  x[ 9 ][ 0 ]  0.35  w[ 0 ]   sum  -0.5319999999999999
#  x[ 9 ][ 1 ]  0.01  w[ 1 ]   sum  -0.5327
# -1.5327  <  0  Hence a -1
#  x[ 10 ][ 0 ]  -0.11  w[ 0 ]   sum  0.16720000000000002
#  x[ 10 ][ 1 ]  0.1  w[ 1 ]   sum  0.1602
# -0.8398  <  0  Hence a -1
# length of weight len( [-1.52, -0.06999999999999995] ) 2
#  x[ 11 ][ 0 ]  0.31  w[ 0 ]   sum  -0.5053000000000001
#  x[ 11 ][ 1 ]  -0.96  w[ 1 ]   sum  -0.5341000000000001
# -0.5341000000000001  <  0  Hence a -1
# length of weight len( [-1.6300000000000001, 0.030000000000000054] ) 2
#  x[ 12 ][ 0 ]  0.0  w[ 0 ]   sum  0.0
#  x[ 12 ][ 1 ]  -0.26  w[ 1 ]   sum  0.2418
# 1.2418  >=  0  Hence a 1
#  x[ 13 ][ 0 ]  -0.43  w[ 0 ]   sum  0.5676
#  x[ 13 ][ 1 ]  -0.65  w[ 1 ]   sum  1.1721
# 2.1721  >=  0  Hence a 1
#  x[ 14 ][ 0 ]  0.57  w[ 0 ]   sum  -0.7524
#  x[ 14 ][ 1 ]  -0.97  w[ 1 ]   sum  0.14969999999999994
# 1.1497  >=  0  Hence a 1
#  x[ 15 ][ 0 ]  -0.72  w[ 0 ]   sum  0.9504
#  x[ 15 ][ 1 ]  -0.64  w[ 1 ]   sum  1.5455999999999999
# 2.5456  >=  0  Hence a 1
#  x[ 16 ][ 0 ]  -0.25  w[ 0 ]   sum  0.33
#  x[ 16 ][ 1 ]  -0.43  w[ 1 ]   sum  0.7299
# 1.7299  >=  0  Hence a 1
#  x[ 17 ][ 0 ]  -0.12  w[ 0 ]   sum  0.1584
#  x[ 17 ][ 1 ]  -0.9  w[ 1 ]   sum  0.9954
# 1.9954  >=  0  Hence a 1
#  x[ 18 ][ 0 ]  -0.58  w[ 0 ]   sum  0.7656
#  x[ 18 ][ 1 ]  0.62  w[ 1 ]   sum  0.18899999999999995
# 1.189  >=  0  Hence a 1
#  x[ 19 ][ 0 ]  -0.77  w[ 0 ]   sum  1.0164
#  x[ 19 ][ 1 ]  -0.76  w[ 1 ]   sum  1.7231999999999998
# 2.7232  >=  0  Hence a 1
#
# ------------------------- ITERATION 2 -------------------------
#  x[ 0 ][ 0 ]  0.72  w[ 0 ]   sum  -0.9504
#  x[ 0 ][ 1 ]  0.82  w[ 1 ]   sum  -1.713
# -0.7130000000000001  <  0  Hence a -1
#  x[ 1 ][ 0 ]  0.91  w[ 0 ]   sum  -1.2012
#  x[ 1 ][ 1 ]  -0.69  w[ 1 ]   sum  -0.5595000000000001
# 0.4404999999999999  >=  0  Hence a 1
# length of weight len( [-1.32, -0.9299999999999999] ) 2
#  x[ 2 ][ 0 ]  0.03  w[ 0 ]   sum  -0.0669
#  x[ 2 ][ 1 ]  0.93  w[ 1 ]   sum  -0.2901
# -0.2901  <  0  Hence a -1
#  x[ 3 ][ 0 ]  0.12  w[ 0 ]   sum  -0.2676
#  x[ 3 ][ 1 ]  0.25  w[ 1 ]   sum  -0.3276
# -0.3276  <  0  Hence a -1
#  x[ 4 ][ 0 ]  0.96  w[ 0 ]   sum  -2.1408
#  x[ 4 ][ 1 ]  0.47  w[ 1 ]   sum  -2.2536
# -2.2536  <  0  Hence a -1
#  x[ 5 ][ 0 ]  0.8  w[ 0 ]   sum  -1.784
#  x[ 5 ][ 1 ]  -0.75  w[ 1 ]   sum  -1.604
# -1.604  <  0  Hence a -1
#  x[ 6 ][ 0 ]  0.46  w[ 0 ]   sum  -1.0258
#  x[ 6 ][ 1 ]  0.98  w[ 1 ]   sum  -1.2610000000000001
# -1.2610000000000001  <  0  Hence a -1
#  x[ 7 ][ 0 ]  0.66  w[ 0 ]   sum  -1.4718
#  x[ 7 ][ 1 ]  0.24  w[ 1 ]   sum  -1.5294
# -1.5294  <  0  Hence a -1
#  x[ 8 ][ 0 ]  0.72  w[ 0 ]   sum  -1.6056
#  x[ 8 ][ 1 ]  -0.15  w[ 1 ]   sum  -1.5695999999999999
# -1.5695999999999999  <  0  Hence a -1
#  x[ 9 ][ 0 ]  0.35  w[ 0 ]   sum  -0.7805
#  x[ 9 ][ 1 ]  0.01  w[ 1 ]   sum  -0.7828999999999999
# -0.7828999999999999  <  0  Hence a -1
#  x[ 10 ][ 0 ]  -0.11  w[ 0 ]   sum  0.2453
#  x[ 10 ][ 1 ]  0.1  w[ 1 ]   sum  0.2213
# 0.2213  >=  0  Hence a 1
#  x[ 11 ][ 0 ]  0.31  w[ 0 ]   sum  -0.6913
#  x[ 11 ][ 1 ]  -0.96  w[ 1 ]   sum  -0.46090000000000003
# -0.46090000000000003  <  0  Hence a -1
# length of weight len( [-2.23, -0.24] ) 2
#  x[ 12 ][ 0 ]  0.0  w[ 0 ]   sum  0.0
#  x[ 12 ][ 1 ]  -0.26  w[ 1 ]   sum  0.312
# 1.312  >=  0  Hence a 1
#  x[ 13 ][ 0 ]  -0.43  w[ 0 ]   sum  0.8256
#  x[ 13 ][ 1 ]  -0.65  w[ 1 ]   sum  1.6056
# 2.6056  >=  0  Hence a 1
#  x[ 14 ][ 0 ]  0.57  w[ 0 ]   sum  -1.0943999999999998
#  x[ 14 ][ 1 ]  -0.97  w[ 1 ]   sum  0.0696000000000001
# 1.0696  >=  0  Hence a 1
#  x[ 15 ][ 0 ]  -0.72  w[ 0 ]   sum  1.3823999999999999
#  x[ 15 ][ 1 ]  -0.64  w[ 1 ]   sum  2.1504
# 3.1504  >=  0  Hence a 1
#  x[ 16 ][ 0 ]  -0.25  w[ 0 ]   sum  0.48
#  x[ 16 ][ 1 ]  -0.43  w[ 1 ]   sum  0.996
# 1.996  >=  0  Hence a 1
#  x[ 17 ][ 0 ]  -0.12  w[ 0 ]   sum  0.2304
#  x[ 17 ][ 1 ]  -0.9  w[ 1 ]   sum  1.3104
# 2.3104  >=  0  Hence a 1
#  x[ 18 ][ 0 ]  -0.58  w[ 0 ]   sum  1.1136
#  x[ 18 ][ 1 ]  0.62  w[ 1 ]   sum  0.36959999999999993
# 1.3696  >=  0  Hence a 1
#  x[ 19 ][ 0 ]  -0.77  w[ 0 ]   sum  1.4784
#  x[ 19 ][ 1 ]  -0.76  w[ 1 ]   sum  2.3903999999999996
# 3.3903999999999996  >=  0  Hence a 1
#
# ------------------------- ITERATION 3 -------------------------
#  x[ 0 ][ 0 ]  0.72  w[ 0 ]   sum  -1.3823999999999999
#  x[ 0 ][ 1 ]  0.82  w[ 1 ]   sum  -2.3663999999999996
# -1.3663999999999996  <  0  Hence a -1
#  x[ 1 ][ 0 ]  0.91  w[ 0 ]   sum  -1.7472
#  x[ 1 ][ 1 ]  -0.69  w[ 1 ]   sum  -0.9192000000000001
# 0.08079999999999987  >=  0  Hence a 1
# length of weight len( [-1.92, -1.2] ) 2
#  x[ 2 ][ 0 ]  0.03  w[ 0 ]   sum  -0.0849
#  x[ 2 ][ 1 ]  0.93  w[ 1 ]   sum  -0.5592
# -0.5592  <  0  Hence a -1
#  x[ 3 ][ 0 ]  0.12  w[ 0 ]   sum  -0.3396
#  x[ 3 ][ 1 ]  0.25  w[ 1 ]   sum  -0.4671
# -0.4671  <  0  Hence a -1
#  x[ 4 ][ 0 ]  0.96  w[ 0 ]   sum  -2.7168
#  x[ 4 ][ 1 ]  0.47  w[ 1 ]   sum  -2.9565
# -2.9565  <  0  Hence a -1
#  x[ 5 ][ 0 ]  0.8  w[ 0 ]   sum  -2.2640000000000002
#  x[ 5 ][ 1 ]  -0.75  w[ 1 ]   sum  -1.8815000000000002
# -1.8815000000000002  <  0  Hence a -1
#  x[ 6 ][ 0 ]  0.46  w[ 0 ]   sum  -1.3018
#  x[ 6 ][ 1 ]  0.98  w[ 1 ]   sum  -1.8016
# -1.8016  <  0  Hence a -1
#  x[ 7 ][ 0 ]  0.66  w[ 0 ]   sum  -1.8678000000000001
#  x[ 7 ][ 1 ]  0.24  w[ 1 ]   sum  -1.9902000000000002
# -1.9902000000000002  <  0  Hence a -1
#  x[ 8 ][ 0 ]  0.72  w[ 0 ]   sum  -2.0376
#  x[ 8 ][ 1 ]  -0.15  w[ 1 ]   sum  -1.9610999999999998
# -1.9610999999999998  <  0  Hence a -1
#  x[ 9 ][ 0 ]  0.35  w[ 0 ]   sum  -0.9904999999999999
#  x[ 9 ][ 1 ]  0.01  w[ 1 ]   sum  -0.9955999999999999
# -0.9955999999999999  <  0  Hence a -1
#  x[ 10 ][ 0 ]  -0.11  w[ 0 ]   sum  0.3113
#  x[ 10 ][ 1 ]  0.1  w[ 1 ]   sum  0.26030000000000003
# 0.26030000000000003  >=  0  Hence a 1
#  x[ 11 ][ 0 ]  0.31  w[ 0 ]   sum  -0.8773
#  x[ 11 ][ 1 ]  -0.96  w[ 1 ]   sum  -0.3877
# -0.3877  <  0  Hence a -1
# length of weight len( [-2.83, -0.51] ) 2
#  x[ 12 ][ 0 ]  0.0  w[ 0 ]   sum  0.0
#  x[ 12 ][ 1 ]  -0.26  w[ 1 ]   sum  0.3822
# 1.3822  >=  0  Hence a 1
#  x[ 13 ][ 0 ]  -0.43  w[ 0 ]   sum  1.0836
#  x[ 13 ][ 1 ]  -0.65  w[ 1 ]   sum  2.0391
# 3.0391  >=  0  Hence a 1
#  x[ 14 ][ 0 ]  0.57  w[ 0 ]   sum  -1.4364
#  x[ 14 ][ 1 ]  -0.97  w[ 1 ]   sum  -0.010499999999999954
# 0.9895  >=  0  Hence a 1
#  x[ 15 ][ 0 ]  -0.72  w[ 0 ]   sum  1.8144
#  x[ 15 ][ 1 ]  -0.64  w[ 1 ]   sum  2.7552
# 3.7552  >=  0  Hence a 1
#  x[ 16 ][ 0 ]  -0.25  w[ 0 ]   sum  0.63
#  x[ 16 ][ 1 ]  -0.43  w[ 1 ]   sum  1.2621
# 2.2621  >=  0  Hence a 1
#  x[ 17 ][ 0 ]  -0.12  w[ 0 ]   sum  0.3024
#  x[ 17 ][ 1 ]  -0.9  w[ 1 ]   sum  1.6254
# 2.6254  >=  0  Hence a 1
#  x[ 18 ][ 0 ]  -0.58  w[ 0 ]   sum  1.4616
#  x[ 18 ][ 1 ]  0.62  w[ 1 ]   sum  0.5502
# 1.5502  >=  0  Hence a 1
#  x[ 19 ][ 0 ]  -0.77  w[ 0 ]   sum  1.9404000000000001
#  x[ 19 ][ 1 ]  -0.76  w[ 1 ]   sum  3.0576
# 4.0576  >=  0  Hence a 1
#
# ------------------------- ITERATION 4 -------------------------
#  x[ 0 ][ 0 ]  0.72  w[ 0 ]   sum  -1.8144
#  x[ 0 ][ 1 ]  0.82  w[ 1 ]   sum  -3.0198
# -2.0198  <  0  Hence a -1
#  x[ 1 ][ 0 ]  0.91  w[ 0 ]   sum  -2.2932
#  x[ 1 ][ 1 ]  -0.69  w[ 1 ]   sum  -1.2789000000000001
# -0.27890000000000015  <  0  Hence a -1
#  x[ 2 ][ 0 ]  0.03  w[ 0 ]   sum  -0.0756
#  x[ 2 ][ 1 ]  0.93  w[ 1 ]   sum  -1.4426999999999999
# -0.44269999999999987  <  0  Hence a -1
#  x[ 3 ][ 0 ]  0.12  w[ 0 ]   sum  -0.3024
#  x[ 3 ][ 1 ]  0.25  w[ 1 ]   sum  -0.6698999999999999
# 0.33010000000000006  >=  0  Hence a 1
# length of weight len( [-2.52, -1.47] ) 2
#  x[ 4 ][ 0 ]  0.96  w[ 0 ]   sum  -2.5344
#  x[ 4 ][ 1 ]  0.47  w[ 1 ]   sum  -3.3428
# -3.3428  <  0  Hence a -1
#  x[ 5 ][ 0 ]  0.8  w[ 0 ]   sum  -2.112
#  x[ 5 ][ 1 ]  -0.75  w[ 1 ]   sum  -0.8220000000000001
# -0.8220000000000001  <  0  Hence a -1
#  x[ 6 ][ 0 ]  0.46  w[ 0 ]   sum  -1.2144000000000001
#  x[ 6 ][ 1 ]  0.98  w[ 1 ]   sum  -2.9000000000000004
# -2.9000000000000004  <  0  Hence a -1
#  x[ 7 ][ 0 ]  0.66  w[ 0 ]   sum  -1.7424000000000002
#  x[ 7 ][ 1 ]  0.24  w[ 1 ]   sum  -2.1552000000000002
# -2.1552000000000002  <  0  Hence a -1
#  x[ 8 ][ 0 ]  0.72  w[ 0 ]   sum  -1.9008
#  x[ 8 ][ 1 ]  -0.15  w[ 1 ]   sum  -1.6428
# -1.6428  <  0  Hence a -1
#  x[ 9 ][ 0 ]  0.35  w[ 0 ]   sum  -0.9239999999999999
#  x[ 9 ][ 1 ]  0.01  w[ 1 ]   sum  -0.9411999999999999
# -0.9411999999999999  <  0  Hence a -1
#  x[ 10 ][ 0 ]  -0.11  w[ 0 ]   sum  0.2904
#  x[ 10 ][ 1 ]  0.1  w[ 1 ]   sum  0.11839999999999998
# 0.11839999999999998  >=  0  Hence a 1
#  x[ 11 ][ 0 ]  0.31  w[ 0 ]   sum  -0.8184
#  x[ 11 ][ 1 ]  -0.96  w[ 1 ]   sum  0.8328
# 0.8328  >=  0  Hence a 1
#  x[ 12 ][ 0 ]  0.0  w[ 0 ]   sum  0.0
#  x[ 12 ][ 1 ]  -0.26  w[ 1 ]   sum  0.4472
# 0.4472  >=  0  Hence a 1
#  x[ 13 ][ 0 ]  -0.43  w[ 0 ]   sum  1.1352
#  x[ 13 ][ 1 ]  -0.65  w[ 1 ]   sum  2.2532
# 2.2532  >=  0  Hence a 1
#  x[ 14 ][ 0 ]  0.57  w[ 0 ]   sum  -1.5048
#  x[ 14 ][ 1 ]  -0.97  w[ 1 ]   sum  0.16359999999999997
# 0.16359999999999997  >=  0  Hence a 1
#  x[ 15 ][ 0 ]  -0.72  w[ 0 ]   sum  1.9008
#  x[ 15 ][ 1 ]  -0.64  w[ 1 ]   sum  3.0016
# 3.0016  >=  0  Hence a 1
#  x[ 16 ][ 0 ]  -0.25  w[ 0 ]   sum  0.66
#  x[ 16 ][ 1 ]  -0.43  w[ 1 ]   sum  1.3996
# 1.3996  >=  0  Hence a 1
#  x[ 17 ][ 0 ]  -0.12  w[ 0 ]   sum  0.3168
#  x[ 17 ][ 1 ]  -0.9  w[ 1 ]   sum  1.8648
# 1.8648  >=  0  Hence a 1
#  x[ 18 ][ 0 ]  -0.58  w[ 0 ]   sum  1.5312
#  x[ 18 ][ 1 ]  0.62  w[ 1 ]   sum  0.4647999999999999
# 0.4647999999999999  >=  0  Hence a 1
#  x[ 19 ][ 0 ]  -0.77  w[ 0 ]   sum  2.0328
#  x[ 19 ][ 1 ]  -0.76  w[ 1 ]   sum  3.34
# 3.34  >=  0  Hence a 1
#
# ------------------------- ITERATION 5 -------------------------
#  x[ 0 ][ 0 ]  0.72  w[ 0 ]   sum  -1.9008
#  x[ 0 ][ 1 ]  0.82  w[ 1 ]   sum  -3.3112
# -3.3112  <  0  Hence a -1
#  x[ 1 ][ 0 ]  0.91  w[ 0 ]   sum  -2.4024
#  x[ 1 ][ 1 ]  -0.69  w[ 1 ]   sum  -1.2156000000000002
# -1.2156000000000002  <  0  Hence a -1
#  x[ 2 ][ 0 ]  0.03  w[ 0 ]   sum  -0.0792
#  x[ 2 ][ 1 ]  0.93  w[ 1 ]   sum  -1.6788
# -1.6788  <  0  Hence a -1
#  x[ 3 ][ 0 ]  0.12  w[ 0 ]   sum  -0.3168
#  x[ 3 ][ 1 ]  0.25  w[ 1 ]   sum  -0.7468
# -0.7468  <  0  Hence a -1
#  x[ 4 ][ 0 ]  0.96  w[ 0 ]   sum  -2.5344
#  x[ 4 ][ 1 ]  0.47  w[ 1 ]   sum  -3.3428
# -3.3428  <  0  Hence a -1
#  x[ 5 ][ 0 ]  0.8  w[ 0 ]   sum  -2.112
#  x[ 5 ][ 1 ]  -0.75  w[ 1 ]   sum  -0.8220000000000001
# -0.8220000000000001  <  0  Hence a -1
#  x[ 6 ][ 0 ]  0.46  w[ 0 ]   sum  -1.2144000000000001
#  x[ 6 ][ 1 ]  0.98  w[ 1 ]   sum  -2.9000000000000004
# -2.9000000000000004  <  0  Hence a -1
#  x[ 7 ][ 0 ]  0.66  w[ 0 ]   sum  -1.7424000000000002
#  x[ 7 ][ 1 ]  0.24  w[ 1 ]   sum  -2.1552000000000002
# -2.1552000000000002  <  0  Hence a -1
#  x[ 8 ][ 0 ]  0.72  w[ 0 ]   sum  -1.9008
#  x[ 8 ][ 1 ]  -0.15  w[ 1 ]   sum  -1.6428
# -1.6428  <  0  Hence a -1
#  x[ 9 ][ 0 ]  0.35  w[ 0 ]   sum  -0.9239999999999999
#  x[ 9 ][ 1 ]  0.01  w[ 1 ]   sum  -0.9411999999999999
# -0.9411999999999999  <  0  Hence a -1
#  x[ 10 ][ 0 ]  -0.11  w[ 0 ]   sum  0.2904
#  x[ 10 ][ 1 ]  0.1  w[ 1 ]   sum  0.11839999999999998
# 0.11839999999999998  >=  0  Hence a 1
#  x[ 11 ][ 0 ]  0.31  w[ 0 ]   sum  -0.8184
#  x[ 11 ][ 1 ]  -0.96  w[ 1 ]   sum  0.8328
# 0.8328  >=  0  Hence a 1
#  x[ 12 ][ 0 ]  0.0  w[ 0 ]   sum  0.0
#  x[ 12 ][ 1 ]  -0.26  w[ 1 ]   sum  0.4472
# 0.4472  >=  0  Hence a 1
#  x[ 13 ][ 0 ]  -0.43  w[ 0 ]   sum  1.1352
#  x[ 13 ][ 1 ]  -0.65  w[ 1 ]   sum  2.2532
# 2.2532  >=  0  Hence a 1
#  x[ 14 ][ 0 ]  0.57  w[ 0 ]   sum  -1.5048
#  x[ 14 ][ 1 ]  -0.97  w[ 1 ]   sum  0.16359999999999997
# 0.16359999999999997  >=  0  Hence a 1
#  x[ 15 ][ 0 ]  -0.72  w[ 0 ]   sum  1.9008
#  x[ 15 ][ 1 ]  -0.64  w[ 1 ]   sum  3.0016
# 3.0016  >=  0  Hence a 1
#  x[ 16 ][ 0 ]  -0.25  w[ 0 ]   sum  0.66
#  x[ 16 ][ 1 ]  -0.43  w[ 1 ]   sum  1.3996
# 1.3996  >=  0  Hence a 1
#  x[ 17 ][ 0 ]  -0.12  w[ 0 ]   sum  0.3168
#  x[ 17 ][ 1 ]  -0.9  w[ 1 ]   sum  1.8648
# 1.8648  >=  0  Hence a 1
#  x[ 18 ][ 0 ]  -0.58  w[ 0 ]   sum  1.5312
#  x[ 18 ][ 1 ]  0.62  w[ 1 ]   sum  0.4647999999999999
# 0.4647999999999999  >=  0  Hence a 1
#  x[ 19 ][ 0 ]  -0.77  w[ 0 ]   sum  2.0328
#  x[ 19 ][ 1 ]  -0.76  w[ 1 ]   sum  3.34
# 3.34  >=  0  Hence a 1
#
# ---------------------------------------------------------------
#
# w[0] w[1]  -2.64   -1.72
#
# Functionality learned with 5 iterations!
#
# Done!

# %%
def get_points_of_color(data, label):
    x_coords = [float(point.split(",")[0]) for point in data.keys() if data[point] == label]
    y_coords = [float(point.split(",")[1]) for point in data.keys() if data[point] == label]
    return x_coords, y_coords

# %%
xA = 1
xB = -1

if w[1] != 0:
    yA = (- w[0] * xA - bias) / w[1]
    yB = (- w[0] * xB - bias) / w[1]

print("xA ",xA," ","xB ",xB," ","yA ",yA," ","yB ",yB," ") 
    
# Plot the black line, that is, we want to learn the black line as faithfully as possible
        #("Best" Decision Boundary)
#plt.plot([0.77, -0.55], [-1, 1], color='k', linestyle='-', linewidth=1)


# Generates our green line, that is, our learning line (Decision Boundary)
plt.plot([xA, xB], [yA, yB], color='g', linestyle='-', linewidth=2)


# Plot blue points
x_coords, y_coords = get_points_of_color(data_dictionary, '-1')
plt.plot(x_coords, y_coords, 'bo')

# Plot red points
x_coords, y_coords = get_points_of_color(data_dictionary, '1')
plt.plot(x_coords, y_coords, 'ro')
# Out:
# xA  1   xB  -1   yA  -1.5348837209302326   yB  1.5348837209302326
